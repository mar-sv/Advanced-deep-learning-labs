# %%
import data_loading_code as loader

# %% [markdown]
# #### **Load data loader**

# %%
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from matplotlib import pyplot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk import word_tokenize
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, classification_report
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_pandas(data, columns):
    df_ = pd.DataFrame(columns=columns)
    data['Sentence'] = data['Sentence'].str.lower()
    data['Sentence'] = data['Sentence'].replace('[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+', '', regex=True)                      # remove emails
    data['Sentence'] = data['Sentence'].replace('((25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)(\.|$)){4}', '', regex=True)    # remove IP address
    data['Sentence'] = data['Sentence'].str.replace('[^\w\s]','')                                                       # remove special characters
    data['Sentence'] = data['Sentence'].replace('\d', '', regex=True)                                                   # remove numbers
    for index, row in data.iterrows():
        word_tokens = word_tokenize(row['Sentence'])
        filtered_sent = [w for w in word_tokens if not w in stopwords.words('english')]
        new_row = pd.DataFrame([{
            "index": row['index'],
            "Class": row['Class'],
            "Sentence": " ".join(filtered_sent)
        }])
        df_ = pd.concat([df_, new_row], ignore_index=True)
    return data

# If this is the primary file that is executed (ie not an import of another file)

# get data, pre-process and split
data = pd.read_csv("amazon_cells_labelled.txt", delimiter='\t', header=None)
data.columns = ['Sentence', 'Class']
data['index'] = data.index                                          # add new column index
columns = ['index', 'Class', 'Sentence']
data = preprocess_pandas(data, columns)                             # pre-process
training_data, validation_data, training_labels, validation_labels = train_test_split( # split the data into training, validation, and test splits
    data['Sentence'].values.astype('U'),
    data['Class'].values.astype('int32'),
    test_size=0.10,
    random_state=0,
    shuffle=True
)

# vectorize data using TFIDF and transform for PyTorch for scalability
word_vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,2), max_features=50000, max_df=0.5, use_idf=True, norm='l2')
training_data = word_vectorizer.fit_transform(training_data)        # transform texts to sparse matrix
training_data = training_data.todense()                             # convert to dense matrix for Pytorch
vocab_size = len(word_vectorizer.vocabulary_)
validation_data = word_vectorizer.transform(validation_data)
validation_data = validation_data.todense()
train_x_tensor = torch.from_numpy(np.array(training_data)).type(torch.FloatTensor)
train_y_tensor = torch.from_numpy(np.array(training_labels)).long()
validation_x_tensor = torch.from_numpy(np.array(validation_data)).type(torch.FloatTensor)
validation_y_tensor = torch.from_numpy(np.array(validation_labels)).long()
# Out:
# [nltk_data] Downloading package punkt to /Users/qasim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/qasim/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# #### **Create chatbot**

# %%
#Here, a very simple text classifier is created.

class TextClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(TextClassifier, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)  
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, output_dim) 

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def train_model(model, train_loader, validation_loader, num_epochs=10):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Lists to store loss per epoch
    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        model.train()  
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for texts, labels in train_loader:
            optimizer.zero_grad()   
            outputs = model(texts)  
            loss = criterion(outputs, labels)  
            loss.backward()         
            optimizer.step()        

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        train_accuracy = 100 * correct_train / total_train

        model.eval()  
        validation_loss = 0.0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for texts, labels in validation_loader:
                outputs = model(texts)
                loss = criterion(outputs, labels)
                validation_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        avg_val_loss = validation_loss / len(validation_loader)
        val_losses.append(avg_val_loss)
        val_accuracy = 100 * correct_val / total_val

        # Print accuracies for each epoch
        print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Validation Accuracy: {val_accuracy:.2f}%')

    print('Finished Training')
    return train_losses, val_losses


batch_size = 64
input_dim = vocab_size  # From how many input dimensions we have
hidden_dim = 100        # 100 hidden neurons
output_dim = 2          # Binary classification. Either positive or negative response



train_dataset = TensorDataset(train_x_tensor, train_y_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

validation_dataset = TensorDataset(validation_x_tensor, validation_y_tensor)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)



model = TextClassifier(input_dim, hidden_dim, output_dim)


criterion = nn.CrossEntropyLoss()
#Learning rate of 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

train_losses, val_losses = train_model(model, train_loader, validation_loader, num_epochs=50)
import matplotlib.pyplot as plt 
# Plotting
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training and Validation Loss Per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50, Training Loss: 0.6899, Validation Loss: 0.6794, Training Accuracy: 56.22%, Validation Accuracy: 85.00%
# Epoch 2/50, Training Loss: 0.6512, Validation Loss: 0.6474, Training Accuracy: 98.11%, Validation Accuracy: 79.00%
# Epoch 3/50, Training Loss: 0.5719, Validation Loss: 0.5934, Training Accuracy: 98.78%, Validation Accuracy: 82.00%
# Epoch 4/50, Training Loss: 0.4491, Validation Loss: 0.5293, Training Accuracy: 99.78%, Validation Accuracy: 83.00%
# Epoch 5/50, Training Loss: 0.3259, Validation Loss: 0.4650, Training Accuracy: 99.78%, Validation Accuracy: 85.00%
# Epoch 6/50, Training Loss: 0.2162, Validation Loss: 0.4153, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 7/50, Training Loss: 0.1401, Validation Loss: 0.3890, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 8/50, Training Loss: 0.0980, Validation Loss: 0.3641, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 9/50, Training Loss: 0.0670, Validation Loss: 0.3530, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 10/50, Training Loss: 0.0494, Validation Loss: 0.3465, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 11/50, Training Loss: 0.0384, Validation Loss: 0.3413, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 12/50, Training Loss: 0.0296, Validation Loss: 0.3357, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 13/50, Training Loss: 0.0248, Validation Loss: 0.3347, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 14/50, Training Loss: 0.0197, Validation Loss: 0.3337, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 15/50, Training Loss: 0.0171, Validation Loss: 0.3300, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 16/50, Training Loss: 0.0147, Validation Loss: 0.3285, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 17/50, Training Loss: 0.0128, Validation Loss: 0.3274, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 18/50, Training Loss: 0.0109, Validation Loss: 0.3246, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 19/50, Training Loss: 0.0099, Validation Loss: 0.3243, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 20/50, Training Loss: 0.0088, Validation Loss: 0.3241, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 21/50, Training Loss: 0.0080, Validation Loss: 0.3238, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 22/50, Training Loss: 0.0072, Validation Loss: 0.3225, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 23/50, Training Loss: 0.0065, Validation Loss: 0.3210, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 24/50, Training Loss: 0.0060, Validation Loss: 0.3204, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 25/50, Training Loss: 0.0058, Validation Loss: 0.3211, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 26/50, Training Loss: 0.0058, Validation Loss: 0.3223, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 27/50, Training Loss: 0.0046, Validation Loss: 0.3229, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 28/50, Training Loss: 0.0042, Validation Loss: 0.3238, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 29/50, Training Loss: 0.0039, Validation Loss: 0.3244, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 30/50, Training Loss: 0.0037, Validation Loss: 0.3242, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 31/50, Training Loss: 0.0035, Validation Loss: 0.3245, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 32/50, Training Loss: 0.0032, Validation Loss: 0.3257, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 33/50, Training Loss: 0.0032, Validation Loss: 0.3266, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 34/50, Training Loss: 0.0029, Validation Loss: 0.3264, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 35/50, Training Loss: 0.0026, Validation Loss: 0.3261, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 36/50, Training Loss: 0.0025, Validation Loss: 0.3261, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 37/50, Training Loss: 0.0024, Validation Loss: 0.3263, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 38/50, Training Loss: 0.0023, Validation Loss: 0.3267, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 39/50, Training Loss: 0.0021, Validation Loss: 0.3276, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 40/50, Training Loss: 0.0022, Validation Loss: 0.3285, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 41/50, Training Loss: 0.0019, Validation Loss: 0.3301, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 42/50, Training Loss: 0.0019, Validation Loss: 0.3302, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 43/50, Training Loss: 0.0017, Validation Loss: 0.3306, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 44/50, Training Loss: 0.0016, Validation Loss: 0.3314, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 45/50, Training Loss: 0.0016, Validation Loss: 0.3319, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 46/50, Training Loss: 0.0015, Validation Loss: 0.3320, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 47/50, Training Loss: 0.0015, Validation Loss: 0.3324, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 48/50, Training Loss: 0.0014, Validation Loss: 0.3329, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 49/50, Training Loss: 0.0014, Validation Loss: 0.3334, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 50/50, Training Loss: 0.0013, Validation Loss: 0.3341, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Finished Training

# %% [markdown]
# ####

# %% [markdown]
# #### **What can be seen is that the validation loss does not improve after 14 epochs, and it starts to increase. This is a sign of overfitting. This means that the final model will be trained with only 14 epochs. The final accuracy is around 87% on the validation set.**

# %%
model = TextClassifier(input_dim, hidden_dim, output_dim)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

train_losses, val_losses = train_model(model, train_loader, validation_loader, num_epochs=14)
torch.save(model.state_dict(), 'text_classifier_model.pth')
# Out:
# Epoch 1/14, Training Loss: 0.6912, Validation Loss: 0.6765, Training Accuracy: 49.67%, Validation Accuracy: 59.00%
# Epoch 2/14, Training Loss: 0.6506, Validation Loss: 0.6413, Training Accuracy: 86.89%, Validation Accuracy: 83.00%
# Epoch 3/14, Training Loss: 0.5688, Validation Loss: 0.5852, Training Accuracy: 99.22%, Validation Accuracy: 86.00%
# Epoch 4/14, Training Loss: 0.4471, Validation Loss: 0.5223, Training Accuracy: 99.67%, Validation Accuracy: 85.00%
# Epoch 5/14, Training Loss: 0.3226, Validation Loss: 0.4641, Training Accuracy: 100.00%, Validation Accuracy: 85.00%
# Epoch 6/14, Training Loss: 0.2193, Validation Loss: 0.4186, Training Accuracy: 100.00%, Validation Accuracy: 84.00%
# Epoch 7/14, Training Loss: 0.1448, Validation Loss: 0.3856, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 8/14, Training Loss: 0.0963, Validation Loss: 0.3675, Training Accuracy: 100.00%, Validation Accuracy: 86.00%
# Epoch 9/14, Training Loss: 0.0686, Validation Loss: 0.3553, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 10/14, Training Loss: 0.0547, Validation Loss: 0.3467, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 11/14, Training Loss: 0.0389, Validation Loss: 0.3419, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 12/14, Training Loss: 0.0309, Validation Loss: 0.3393, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 13/14, Training Loss: 0.0255, Validation Loss: 0.3361, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Epoch 14/14, Training Loss: 0.0213, Validation Loss: 0.3354, Training Accuracy: 100.00%, Validation Accuracy: 87.00%
# Finished Training

# %%
def prepare_input(text, word_vectorizer):
    vectorized_text = word_vectorizer.transform([text]).todense()  # Vectorize the text
    input_tensor = torch.from_numpy(np.array(vectorized_text)).type(torch.FloatTensor)
    return input_tensor

def generate_response(class_id):
    responses = {
        0: "Negative response.",
        1: "Positive response."
    }
    return responses.get(class_id, "Unknown class response.")

def predict_and_respond(input_text, model, word_vectorizer):
    input_tensor = prepare_input(input_text, word_vectorizer)
    with torch.no_grad():
        output = model(input_tensor)
        _, predicted_class = torch.max(output, 1)
        return generate_response(predicted_class.item())

def main_loop(model, word_vectorizer):
    model.eval()  # Set the model to evaluation mode
    print("Type 'quit' to exit the program.")
    while True:
        input_text = input("You: ")
        if input_text.lower() == 'quit':
            print("Exiting the program.")
            break
        response = predict_and_respond(input_text, model, word_vectorizer)
        print(f'User: {input_text}')
        print("Bot:", response)

#Load previously trained model
model.load_state_dict(torch.load('text_classifier_model.pth'))

#Create a loop which takes inputs, and generates output
main_loop(model, word_vectorizer)
# Out:
# Type 'quit' to exit the program.
# You: This is a nice phone
# User: This is a nice phone
# Bot: Positive response.
# You: Bad phone
# User: Bad phone
# Bot: Negative response.
# You: I like you
# User: I like you
# Bot: Negative response.
# You: Not an Excellent phone
# User: Not an Excellent phone
# Bot: Positive response.
# You: quit
# Exiting the program.
